# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("C:\\Users\\shiko\\Desktop\\datascienceintership\\TASK 2\\Titanic-Dataset2.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#deletr unused columns
dff=df.drop(columns=[ 'PassengerId', 'Cabin', 'Ticket'])

# %%
#delete missing values
df_dropped_na = dff.dropna()
df_reset = df_dropped_na.reset_index(drop=True)
df_reset
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 707         0       3               Rice, Mrs. William (Margaret Norton)
# 708         0       2                              Montvila, Rev. Juozas
# 709         1       1                       Graham, Miss. Margaret Edith
# 710         1       1                              Behr, Mr. Karl Howell
# 711         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch     Fare Embarked
# ...

# %%
#check if there is any wrong value
wrong_values=df_reset[(df_reset['Age']<0) | (df_reset['Age']>100) | (df_reset['Fare']<0) ]
wrong_values
# Out:
# Empty DataFrame
# Columns: [Survived, Pclass, Name, Sex, Age, SibSp, Parch, Fare, Embarked]
# Index: []

# %%
print(df_reset['Age'].value_counts())
print(df_reset['Sex'].value_counts())
print(df_reset['Fare'].value_counts())
print(df_reset['Survived'].value_counts())
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 28.00    25
# 30.00    25
#          ..
# 24.50     1
# 0.67      1
# 0.42      1
# 34.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64
# Sex
# male      453
# female    259
# Name: count, dtype: int64
# Fare
# 13.0000    41
# 26.0000    30
# 8.0500     29
# 10.5000    24
# 7.8958     23
#            ..
# 13.8583     1
# 50.4958     1
# 5.0000      1
# 9.8458      1
# 10.5167     1
# Name: count, Length: 219, dtype: int64
# Survived
# 0    424
# 1    288
# Name: count, dtype: int64

# %%
sns.boxplot(x=df_reset['Age'])
plt.show()
plt.figure(figsize=(10,6))
df_reset['Fare'].hist(bins=30,edgecolor='black')
plt.xlabel('fare')
plt.ylabel('Frequency')
plt.show()

# %%
# check the fare
df_fare=df_reset[ (df_reset['Fare']>263) ]
df_fare
# There is three special tickets
# Out:
#      Survived  Pclass                                Name     Sex   Age  \
# 207         1       1                    Ward, Miss. Anna  female  35.0
# 536         1       1  Cardeza, Mr. Thomas Drake Martinez    male  36.0
# 586         1       1              Lesurer, Mr. Gustave J    male  35.0
#
#      SibSp  Parch      Fare Embarked
# 207      0      0  512.3292        C
# 536      0      1  512.3292        C
# 586      0      0  512.3292        C

# %%
plt.figure(figsize=(15,7))
sns.scatterplot(x='Fare',y='Survived',data=df_reset)
plt.title('Fare vs Survival')
plt.show()

# %%
sns.distplot(df_reset['Survived'],kde=False,bins=25)
# Out:
# C:\Users\shiko\AppData\Local\Temp\ipykernel_9304\2630243154.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_reset['Survived'],kde=False,bins=25)
# <Axes: xlabel='Survived'>

# %%
sns.pairplot(df_reset)
